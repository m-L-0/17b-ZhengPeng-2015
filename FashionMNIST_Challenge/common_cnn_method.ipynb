# %%
import tensorflow.examples.tutorials.mnist.input_data as input_data

mnist = input_data.read_data_sets("MNIST_data/fashion/", one_hot=True)

# start tensorflow interactiveSession
import tensorflow as tf

sess = tf.InteractiveSession()


# weight initialization
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)


def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)


# convolution
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')


# pooling
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')


# Create the model
# placeholder
x = tf.placeholder("float", [None, 784])
y_ = tf.placeholder("float", [None, 10])
# variables
W = tf.Variable(tf.zeros([784, 10]))
b = tf.Variable(tf.zeros([10]))

y = tf.nn.softmax(tf.matmul(x, W) + b)

# first convolutinal layer
w_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])

x_image = tf.reshape(x, [-1, 28, 28, 1])

h_conv1 = tf.nn.relu(conv2d(x_image, w_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

# second convolutional layer
w_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1, w_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

# densely connected layer
w_fc1 = weight_variable([7 * 7 * 64, 1024])
b_fc1 = bias_variable([1024])

h_pool2_flat = tf.reshape(h_pool2, [-1, 7 * 7 * 64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, w_fc1) + b_fc1)

# dropout
keep_prob = tf.placeholder("float")
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# readout layer
w_fc2 = weight_variable([1024, 10])
b_fc2 = bias_variable([10])

y_conv = tf.nn.softmax(tf.matmul(h_fc1_drop, w_fc2) + b_fc2)

# train and evaluate the model
cross_entropy = -tf.reduce_sum(y_ * tf.log(y_conv))
# train_step = tf.train.AdagradOptimizer(1e-4).minimize(cross_entropy)
train_step = tf.train.GradientDescentOptimizer(1e-3).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
sess.run(tf.global_variables_initializer())
for i in range(20000):
    batch = mnist.train.next_batch(50)
    if i % 100 == 0:
        train_accuracy = accuracy.eval(feed_dict={x: batch[0], y_: batch[1], keep_prob: 0.3})
        print("step %d, train accuracy %g" % (i, train_accuracy))
    train_step.run(feed_dict={x: batch[0], y_: batch[1], keep_prob: 0.3})

# 显存不足错误
# print("test accuracy %g" % accuracy.eval(feed_dict={x: mnist.test.images, y_: mnist.test.labels, keep_prob: 1.0}))
a = 10
b = 50
sum = 0
for i in range(a):
    testSet = mnist.test.next_batch(b)
    c = accuracy.eval(feed_dict={x: testSet[0], y_: testSet[1], keep_prob: 1.0})
    sum += c * b
    #print("test accuracy %g" %  c)
print("test accuracy %g" %  (sum / (b * a)))
# Out:
# Extracting MNIST_data/fashion/train-images-idx3-ubyte.gz
# Extracting MNIST_data/fashion/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/fashion/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/fashion/t10k-labels-idx1-ubyte.gz
# step 0, train accuracy 0.12
# step 100, train accuracy 0.66
# step 200, train accuracy 0.68
# step 300, train accuracy 0.8
# step 400, train accuracy 0.84
# step 500, train accuracy 0.84
# step 600, train accuracy 0.86
# step 700, train accuracy 0.84
# step 800, train accuracy 0.9
# step 900, train accuracy 0.78
# step 1000, train accuracy 0.74
# step 1100, train accuracy 0.8
# step 1200, train accuracy 0.9
# step 1300, train accuracy 0.86
# step 1400, train accuracy 0.9
# step 1500, train accuracy 0.84
# step 1600, train accuracy 0.8
# step 1700, train accuracy 0.84
# step 1800, train accuracy 0.86
# step 1900, train accuracy 0.8
# step 2000, train accuracy 0.8
# step 2100, train accuracy 0.82
# step 2200, train accuracy 0.8
# step 2300, train accuracy 0.84
# step 2400, train accuracy 0.84
# step 2500, train accuracy 0.92
# step 2600, train accuracy 0.88
# step 2700, train accuracy 0.8
# step 2800, train accuracy 0.9
# step 2900, train accuracy 0.86
# step 3000, train accuracy 0.98
# step 3100, train accuracy 0.86
# step 3200, train accuracy 0.84
# step 3300, train accuracy 0.96
# step 3400, train accuracy 0.92
# step 3500, train accuracy 0.92
# step 3600, train accuracy 0.86
# step 3700, train accuracy 0.82
# step 3800, train accuracy 0.84
# step 3900, train accuracy 0.86
# step 4000, train accuracy 0.9
# step 4100, train accuracy 0.92
# step 4200, train accuracy 0.9
# step 4300, train accuracy 0.84
# step 4400, train accuracy 0.86
# step 4500, train accuracy 0.92
# step 4600, train accuracy 0.86
# step 4700, train accuracy 0.88
# step 4800, train accuracy 0.88
# step 4900, train accuracy 0.88
# step 5000, train accuracy 0.92
# step 5100, train accuracy 0.94
# step 5200, train accuracy 0.94
# step 5300, train accuracy 0.88
# step 5400, train accuracy 0.92
# step 5500, train accuracy 0.86
# step 5600, train accuracy 0.86
# step 5700, train accuracy 0.8
# step 5800, train accuracy 0.86
# step 5900, train accuracy 0.9
# step 6000, train accuracy 0.86
# step 6100, train accuracy 0.94
# step 6200, train accuracy 0.88
# step 6300, train accuracy 0.84
# step 6400, train accuracy 0.82
# step 6500, train accuracy 0.92
# step 6600, train accuracy 0.92
# step 6700, train accuracy 0.86
# step 6800, train accuracy 0.82
# step 6900, train accuracy 0.92
# step 7000, train accuracy 0.84
# step 7100, train accuracy 0.8
# step 7200, train accuracy 0.96
# step 7300, train accuracy 0.92
# step 7400, train accuracy 0.94
# step 7500, train accuracy 0.96
# step 7600, train accuracy 0.98
# step 7700, train accuracy 0.94
# step 7800, train accuracy 0.8
# step 7900, train accuracy 0.82
# step 8000, train accuracy 0.94
# step 8100, train accuracy 0.9
# step 8200, train accuracy 0.94
# step 8300, train accuracy 0.78
# step 8400, train accuracy 0.9
# step 8500, train accuracy 0.92
# step 8600, train accuracy 0.92
# step 8700, train accuracy 0.9
# step 8800, train accuracy 0.88
# step 8900, train accuracy 0.9
# step 9000, train accuracy 0.84
# step 9100, train accuracy 0.86
# step 9200, train accuracy 0.94
# step 9300, train accuracy 0.88
# step 9400, train accuracy 0.86
# step 9500, train accuracy 0.88
# step 9600, train accuracy 0.84
# step 9700, train accuracy 0.92
# step 9800, train accuracy 0.9
# step 9900, train accuracy 0.92
# step 10000, train accuracy 0.92
# step 10100, train accuracy 0.86
# step 10200, train accuracy 0.92
# step 10300, train accuracy 0.82
# step 10400, train accuracy 0.9
# step 10500, train accuracy 0.88
# step 10600, train accuracy 0.9
# step 10700, train accuracy 0.9
# step 10800, train accuracy 0.92
# step 10900, train accuracy 0.84
# step 11000, train accuracy 0.86
# step 11100, train accuracy 0.84
# step 11200, train accuracy 0.86
# step 11300, train accuracy 0.98
# step 11400, train accuracy 0.92
# step 11500, train accuracy 0.9
# step 11600, train accuracy 0.86
# step 11700, train accuracy 0.86
# step 11800, train accuracy 0.88
# step 11900, train accuracy 0.94
# step 12000, train accuracy 0.92
# step 12100, train accuracy 0.92
# step 12200, train accuracy 0.86
# step 12300, train accuracy 0.9
# step 12400, train accuracy 0.88
# step 12500, train accuracy 0.86
# step 12600, train accuracy 0.86
# step 12700, train accuracy 0.9
# step 12800, train accuracy 0.92
# step 12900, train accuracy 0.92
# step 13000, train accuracy 0.82
# step 13100, train accuracy 0.88
# step 13200, train accuracy 0.88
# step 13300, train accuracy 0.82
# step 13400, train accuracy 0.92
# step 13500, train accuracy 0.9
# step 13600, train accuracy 0.86
# step 13700, train accuracy 0.88
# step 13800, train accuracy 0.92
# step 13900, train accuracy 0.88
# step 14000, train accuracy 0.96
# step 14100, train accuracy 0.92
# step 14200, train accuracy 0.86
# step 14300, train accuracy 0.92
# step 14400, train accuracy 0.88
# step 14500, train accuracy 0.9
# step 14600, train accuracy 0.94
# step 14700, train accuracy 0.88
# step 14800, train accuracy 0.92
# step 14900, train accuracy 0.88
# step 15000, train accuracy 0.86
# step 15100, train accuracy 0.88
# step 15200, train accuracy 0.94
# step 15300, train accuracy 0.84
# step 15400, train accuracy 0.78
# step 15500, train accuracy 0.94
# step 15600, train accuracy 0.96
# step 15700, train accuracy 0.84
# step 15800, train accuracy 0.9
# step 15900, train accuracy 0.96
# step 16000, train accuracy 0.94
# step 16100, train accuracy 0.92
# step 16200, train accuracy 0.94
# step 16300, train accuracy 0.9
# step 16400, train accuracy 0.86
# step 16500, train accuracy 0.9
# step 16600, train accuracy 0.92
# step 16700, train accuracy 0.92
# step 16800, train accuracy 0.96
# step 16900, train accuracy 0.96
# step 17000, train accuracy 0.9
# step 17100, train accuracy 0.94
# step 17200, train accuracy 0.98
# step 17300, train accuracy 0.92
# step 17400, train accuracy 0.9
# step 17500, train accuracy 0.92
# step 17600, train accuracy 0.92
# step 17700, train accuracy 0.86
# step 17800, train accuracy 0.9
# step 17900, train accuracy 0.9
# step 18000, train accuracy 0.8
# step 18100, train accuracy 0.84
# step 18200, train accuracy 0.94
# step 18300, train accuracy 0.84
# step 18400, train accuracy 0.88
# step 18500, train accuracy 0.92
# step 18600, train accuracy 0.86
# step 18700, train accuracy 0.92
# step 18800, train accuracy 0.94
# step 18900, train accuracy 0.9
# step 19000, train accuracy 0.92
# step 19100, train accuracy 0.94
# step 19200, train accuracy 0.94
# step 19300, train accuracy 0.88
# step 19400, train accuracy 0.86
# step 19500, train accuracy 0.9
# step 19600, train accuracy 0.98
# step 19700, train accuracy 0.94
# step 19800, train accuracy 0.8
# step 19900, train accuracy 0.86
# test accuracy 0.924
